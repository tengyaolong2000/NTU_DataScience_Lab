# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
pathname = "/Users/tengyaolong/Desktop/NTU_DataScience_Lab/house-prices-advanced-regression-techniques/train.csv"
df = pd.read_csv(pathname);
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#new_df with only int 64
new_df = df.select_dtypes(include='int64')

# %%
new_df
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# ...

# %%
numeric_data = df.drop(['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',\
        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath' ,\
        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish','GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'], axis=1)

# %%
numeric_data
# Out:
#         Id  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0        1         65.0     8450       196.0         706           0
# 1        2         80.0     9600         0.0         978           0
# 2        3         68.0    11250       162.0         486           0
# 3        4         60.0     9550         0.0         216           0
# 4        5         84.0    14260       350.0         655           0
# ...    ...          ...      ...         ...         ...         ...
# 1455  1456         62.0     7917         0.0           0           0
# 1456  1457         85.0    13175       119.0         790         163
# 1457  1458         66.0     9042         0.0         275           0
# 1458  1459         68.0     9717         0.0          49        1029
# 1459  1460         75.0     9937         0.0         830         290
#
#       BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  ...  WoodDeckSF  \
# 0           150          856       856       854  ...           0
# ...

# %%
numeric_data.describe()
# Out:
#                 Id  LotFrontage        LotArea   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1201.000000    1460.000000  1452.000000  1460.000000
# mean    730.500000    70.049958   10516.828082   103.685262   443.639726
# std     421.610009    24.284752    9981.264932   181.066207   456.098091
# min       1.000000    21.000000    1300.000000     0.000000     0.000000
# 25%     365.750000    59.000000    7553.500000     0.000000     0.000000
# 50%     730.500000    69.000000    9478.500000     0.000000   383.500000
# 75%    1095.250000    80.000000   11601.500000   166.000000   712.250000
# max    1460.000000   313.000000  215245.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466  ...
# std     161.319273   441.866955   438.705324   386.587738   436.528436  ...
# ...

# %%
numeric_data.median()
# Out:
# Id                  730.5
# LotFrontage          69.0
# LotArea            9478.5
# MasVnrArea            0.0
# BsmtFinSF1          383.5
# BsmtFinSF2            0.0
# BsmtUnfSF           477.5
# TotalBsmtSF         991.5
# 1stFlrSF           1087.0
# 2ndFlrSF              0.0
# LowQualFinSF          0.0
# GrLivArea          1464.0
# BedroomAbvGr          3.0
# KitchenAbvGr          1.0
# Fireplaces            1.0
# GarageCars            2.0
# GarageArea          480.0
# WoodDeckSF            0.0
# OpenPorchSF          25.0
# EnclosedPorch         0.0
# 3SsnPorch             0.0
# ScreenPorch           0.0
# PoolArea              0.0
# MiscVal               0.0
# MoSold                6.0
# YrSold             2008.0
# SalePrice        163000.0
# dtype: float64

# %%
f, axes = plt.subplots(27, 3, figsize=(18, 24))

count = 0
for var in numeric_data:
    sb.boxplot(data = numeric_data[var], orient = "h", ax = axes[count,0])
    sb.histplot(data = numeric_data[var], ax = axes[count,1])
    sb.kdeplot(data = numeric_data[var], ax = axes[count,2])
    count += 1

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-66b1dd8ba9ac> in <module>
#       5     sb.boxplot(data = numeric_data[var], orient = "h", ax = axes[count,0])
#       6     sb.histplot(data = numeric_data[var], ax = axes[count,1])
# ----> 7     sb.kdeplot(data = numeric_data[var], orient = "h", ax = axes[count,2])
#       8     count += 1
#       9
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
