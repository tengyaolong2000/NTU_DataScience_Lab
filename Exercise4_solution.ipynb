# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\teng0144\Desktop\train.csv")
df1 = df.copy()

x = df["GrLivArea"]
y = df["SalePrice"]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=True)

#we need to reshape to 2d array for sklearn
x_train = x_train.values.reshape(-1,1)
x_test = x_test.values.reshape(-1,1)
y_train = y_train.values.reshape(-1,1)
y_test = y_test.values.reshape(-1,1)

print("Train Set :", x_train.shape, y_train.shape)
print("Test Set  :", x_test.shape, y_test.shape)
# Out:
# Train Set : (1168, 1) (1168, 1)
# Test Set  : (292, 1) (292, 1)

# %%
linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [8664.86918726]
# Coefficients 	: a =  [[113.48762342]]

# %%
# Formula for the Regression line
regline_x = x_train
regline_y = linreg.intercept_ + linreg.coef_ * x_train

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(x_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %%
# Predict 
y_train_pred = linreg.predict(x_train)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(x_train, y_train)
plt.scatter(x_train, y_train_pred, color = "r")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

y_test_pred = linreg.predict(x_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.525152228800817
# Mean Squared Error (MSE) 	: 3007169992.2708874
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.3990287821793781
# Mean Squared Error (MSE) 	: 3726660869.725739

# %% [markdown]
# # Question 2

# %% [markdown]
# GarageArea

# %%
x_gr = df["GarageArea"]
y_gr = df["SalePrice"]

x_train_gr, x_test_gr, y_train_gr, y_test_gr = train_test_split(x_gr, y_gr, test_size=0.2, shuffle=True)

#we need to reshape to 2d array for sklearn
x_train_gr = x_train_gr.values.reshape(-1,1)
x_test_gr = x_test_gr.values.reshape(-1,1)
y_train_gr = y_train_gr.values.reshape(-1,1)
y_test_gr = y_test_gr.values.reshape(-1,1)

print("Train Set :", x_train_gr.shape, y_train_gr.shape)
print("Test Set  :", x_test_gr.shape, y_test_gr.shape)

linreg_gr = LinearRegression()
linreg_gr.fit(x_train_gr, y_train_gr)
# Out:
# Train Set : (1168, 1) (1168, 1)
# Test Set  : (292, 1) (292, 1)
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg_gr.intercept_)
print('Coefficients \t: a = ', linreg_gr.coef_)
# Out:
# Intercept 	: b =  [73409.18531053]
# Coefficients 	: a =  [[223.6259921]]

# %%
# Formula for the Regression line
regline_x_gr = x_train_gr
regline_y_gr = linreg_gr.intercept_ + linreg_gr.coef_ * x_train_gr

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(x_train_gr, y_train_gr)
plt.plot(regline_x_gr, regline_y_gr, 'r-', linewidth = 3)
plt.show()

# %%
# Predict 
y_train_pred_gr = linreg_gr.predict(x_train_gr)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(x_train_gr, y_train_gr)
plt.scatter(x_train_gr, y_train_pred_gr, color = "r")
plt.show()

# %%
y_test_pred_gr = linreg_gr.predict(x_test_gr)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg_gr.score(x_train_gr, y_train_gr))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train_gr, y_train_pred_gr))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg_gr.score(x_test_gr, y_test_gr))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test_gr, y_test_pred_gr))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.39804324973336225
# Mean Squared Error (MSE) 	: 3319880132.24857
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.3600107369075408
# Mean Squared Error (MSE) 	: 6028078424.980817

# %% [markdown]
# TotalBsmtSF

# %%
x_bs = df["TotalBsmtSF"]
y_bs = df["SalePrice"]

x_train_bs, x_test_bs, y_train_bs, y_test_bs = train_test_split(x_bs, y_bs, test_size=0.2, shuffle=True)

#we need to reshape to 2d array for sklearn
x_train_bs = x_train_bs.values.reshape(-1,1)
x_test_bs = x_test_bs.values.reshape(-1,1)
y_train_bs = y_train_bs.values.reshape(-1,1)
y_test_bs = y_test_bs.values.reshape(-1,1)

print("Train Set :", x_train_bs.shape, y_train_bs.shape)
print("Test Set  :", x_test_bs.shape, y_test_bs.shape)

linreg_bs = LinearRegression()
linreg_bs.fit(x_train_bs, y_train_bs)
# Out:
# Train Set : (1168, 1) (1168, 1)
# Test Set  : (292, 1) (292, 1)
# LinearRegression()

# %%
print('Intercept \t: b = ', linreg_bs.intercept_)
print('Coefficients \t: a = ', linreg_bs.coef_)
# Out:
# Intercept 	: b =  [69747.85147318]
# Coefficients 	: a =  [[105.45921364]]

# %%
# Formula for the Regression line
regline_x_bs = x_train_bs
regline_y_bs = linreg_bs.intercept_ + linreg_bs.coef_ * x_train_bs

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(x_train_bs, y_train_bs)
plt.plot(regline_x_bs, regline_y_bs, 'r-', linewidth = 3)
plt.show()

# %%
# Predict 
y_train_pred_bs = linreg_bs.predict(x_train_bs)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(x_train_bs, y_train_bs)
plt.scatter(x_train_bs, y_train_pred_bs, color = "r")
plt.show()

# %%
y_test_pred_bs = linreg_bs.predict(x_test_bs)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg_bs.score(x_train_bs, y_train_bs))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train_bs, y_train_pred_bs))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg_bs.score(x_test_bs, y_test_bs))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test_bs, y_test_pred_bs))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.3530811115461654
# Mean Squared Error (MSE) 	: 4007990466.73764
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.45770055827555745
# Mean Squared Error (MSE) 	: 3661336311.961267

# %% [markdown]
# # Problem 3

# %%
IQR = df1["GrLivArea"].quantile(0.75)-df["GrLivArea"].quantile(0.25)
upper = df1["GrLivArea"].quantile(0.75)+1.5*IQR
lower = df1["GrLivArea"].quantile(0.25)-1.5*IQR

IQR1 = df1["SalePrice"].quantile(0.75)-df["SalePrice"].quantile(0.25)
upper1 = df1["SalePrice"].quantile(0.75)+1.5*IQR1
lower1 = df1["SalePrice"].quantile(0.25)-1.5*IQR1

index_out = df1[(df1["SalePrice"]>upper1) | (df1["SalePrice"]<lower1) | (df1["GrLivArea"]>upper) | (df1["GrLivArea"]<lower) ].index
df1.drop(index_out, inplace=True)

# %%
features = ["GrLivArea", "SalePrice"]
for _ in features:
    IQR = df[_].quantile(0.75)-df[_].quantile(0.25)
    print("Number of "+_+" outliers:" \
          , (df[_]> df[_].quantile(0.75)+1.5*IQR).sum()+ (df[_]<df[_].quantile(0.25)-1.5*IQR).sum())
# Out:
# Number of GrLivArea outliers: 31
# Number of SalePrice outliers: 61

# %%
x_new = df1["GrLivArea"]
y_new = df1["SalePrice"]

x_train_new, x_test_new, y_train_new, y_test_new = train_test_split(x_new, y_new, test_size=0.2, shuffle=True)

#we need to reshape to 2d array for sklearn
x_train_new = x_train_new.values.reshape(-1,1)
x_test_new = x_test_new.values.reshape(-1,1)
y_train_new = y_train_new.values.reshape(-1,1)
y_test_new = y_test_new.values.reshape(-1,1)

print("Train Set :", x_train_new.shape, y_train_new.shape)
print("Test Set  :", x_test_new.shape, y_test_new.shape)

linreg_new = LinearRegression()
linreg_new.fit(x_train_new, y_train_new)

f = plt.figure(figsize=(16, 8))
plt.scatter(df["GrLivArea"], df["SalePrice"])
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.axvline(upper)
plt.axvline(lower)
plt.axhline(upper1)
plt.axhline(lower1)
plt.show()
# Out:
# Train Set : (1106, 1) (1106, 1)
# Test Set  : (277, 1) (277, 1)

# %%
# Formula for the Regression line
regline_x_new = x_train_new
regline_y_new = linreg_new.intercept_ + linreg_new.coef_ * x_train_new

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(x_train_new, y_train_new)
plt.plot(regline_x_new, regline_y_new, 'r-', linewidth = 3)
plt.show()

# %%
# Predict 
y_train_pred_new = linreg_new.predict(x_train_new)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(x_train_new, y_train_new)
plt.scatter(x_train_new, y_train_pred_new, color = "r")
plt.show()

# %%
y_test_pred_new = linreg_new.predict(x_test_new)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_train_new, y_train_new))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train_new, y_train_pred_new))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(x_test_new, y_test_new))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test_new, y_test_pred_new))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.451278256802917
# Mean Squared Error (MSE) 	: 1762016427.6469374
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.44199520327191855
# Mean Squared Error (MSE) 	: 1955264935.0264733

# %%
"""Problem 3's Model is better since it has higher R^2 value and lower MSE. """
# Out:
# "Problem 3's Model is better since it has higher R^2 value and lower MSE. "

# %%
"""Goodness of Fit of Model 	Train Dataset
Explained Variance (R^2) 	: 0.525152228800817
Mean Squared Error (MSE) 	: 3007169992.2708874

Goodness of Fit of Model 	Test Dataset
Explained Variance (R^2) 	: 0.3990287821793781
Mean Squared Error (MSE) 	: 3726660869.725739 """
# Out:
# 'Goodness of Fit of Model \tTrain Dataset\nExplained Variance (R^2) \t: 0.525152228800817\nMean Squared Error (MSE) \t: 3007169992.2708874\n\nGoodness of Fit of Model \tTest Dataset\nExplained Variance (R^2) \t: 0.3990287821793781\nMean Squared Error (MSE) \t: 3726660869.725739 '
