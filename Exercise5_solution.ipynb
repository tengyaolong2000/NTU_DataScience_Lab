# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import plot_tree
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv(r"C:\Users\teng0144\Desktop\train.csv")
X=pd.DataFrame(df['SalePrice'])
Y=pd.DataFrame(df['CentralAir'])
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, shuffle=True)

# %%
len(df[df['CentralAir']=='Y'])
# Out:
# 1365

# %%
dectree2 = DecisionTreeClassifier(max_depth = 2)  # create the decision tree object
dectree2.fit(x_train, y_train)

f = plt.figure(figsize=(12,12))
plot_tree(dectree2, filled=True, rounded=True, 
          feature_names=["SalePrice"], 
          class_names=["No","Yes"])

# Predict Legendary corresponding to Total Test
test_pred2 = dectree2.predict(x_test)

plt.show()

# %%
# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree2.score(x_test, y_test))

# Plot the two-way Confusion Matrix
sb.heatmap(confusion_matrix(y_test, test_pred2), 
           annot = True, fmt=".0f", annot_kws={"size": 18})
plt.show()
# Out:
# Classification Accuracy 	: 0.952054794520548

# %%
#True Positive Rate 0.99257, False Positive Rate 0.86667

# %%
dectree4 = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
dectree4.fit(x_train, y_train)
dectree4.fit(x_train, y_train)# train the decision tree model

f = plt.figure(figsize=(12,12))
plot_tree(dectree4, filled=True, rounded=True, 
          feature_names=["SalePrice"], 
          class_names=["No","Yes"])
plt.show()

# %%
test_pred4 = dectree4.predict(x_test)

# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree4.score(x_test, y_test))

# Plot the two-way Confusion Matrix
sb.heatmap(confusion_matrix(y_test, test_pred4), 
           annot = True, fmt=".0f", annot_kws={"size": 18})
plt.show()
# Out:
# Classification Accuracy 	: 0.9383561643835616

# %%
#True Positive Rate 0.97833, False Positive Rate 0.80

# %% [markdown]
# # 2

# %%
y_m = pd.DataFrame(df["CentralAir"])
x_m = pd.DataFrame(df['OverallQual'])
x_train_m, x_test_m, y_train_m, y_test_m = train_test_split(x_m, y_m, test_size = 0.2, shuffle=True)

dectree_m = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
dectree_m.fit(x_train_m, y_train_m)

f = plt.figure(figsize=(12,12))
plot_tree(dectree_m, filled=True, rounded=True, 
          feature_names=['OverallQual'], 
          class_names=["No","Yes"])

# Predict Legendary corresponding to Total Test
test_pred_m = dectree_m.predict(x_test_m)

plt.show()

# %%
# Predict Legendary corresponding to Total Test
test_pred_m = dectree_m.predict(x_test_m)

# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree_m.score(x_test_m, y_test_m))

# Plot the two-way Confusion Matrix
sb.heatmap(confusion_matrix(y_test_m, test_pred_m), 
           annot = True, fmt=".0f", annot_kws={"size": 18})
plt.show()
# Out:
# Classification Accuracy 	: 0.9315068493150684

# %%
y_m1 = pd.DataFrame(df["CentralAir"])
x_m1 = pd.DataFrame(df['YearBuilt'])
x_train_m1, x_test_m1, y_train_m1, y_test_m1 = train_test_split(x_m1, y_m1, test_size = 0.2, shuffle=True)

dectree_m1 = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
dectree_m1.fit(x_train_m1, y_train_m1)

f = plt.figure(figsize=(12,12))
plot_tree(dectree_m1, filled=True, rounded=True, 
          feature_names=['YearBuilt'], 
          class_names=["No","Yes"])

test_pred_m1 = dectree_m.predict(x_test_m1)

plt.show()

# %%
test_pred_m1 = dectree_m1.predict(x_test_m1)

# Print the Classification Accuracy
print("Classification Accuracy \t:", dectree_m.score(x_test_m1, y_test_m))

# Plot the two-way Confusion Matrix
sb.heatmap(confusion_matrix(y_test_m1, test_pred_m1), 
           annot = True, fmt=".0f", annot_kws={"size": 18})
plt.show()
# Out:
# Classification Accuracy 	: 0.9212328767123288

# %%
#YearBuilt since lower false positive

# %% [markdown]
# ### 3

# %%
f = plt.figure(figsize=(50,50))
plot_tree(dectree4, filled=True, rounded=True, 
          feature_names=["SalePrice"], 
          class_names=["No","Yes"])

# Predict Legendary corresponding to Total Test
test_pred4 = dectree4.predict(x_test)

plt.show()

# %%
x_copy = x_train.copy()
y_copy = y_train.copy()

new_df = pd.concat([x_copy, y_copy], axis=1)
fp = new_df[(new_df["SalePrice"]<107450) & (new_df["SalePrice"]>61691.5) &  (new_df["SalePrice"]>=79450) & (new_df["SalePrice"]<=105950)]
fp.shape
# Out:
# (91, 2)

# %%
fp[fp['CentralAir']=='N']
# Out:
#       SalePrice CentralAir
# 98        83000          N
# 1035      84000          N
# 456       98000          N
# 1412      90000          N
# 998       91000          N
# 39        82000          N
# 671      103600          N
# 912       88000          N
# 1062      90000          N
# 125       84500          N
# 821       93000          N
# 1135     102000          N
# 1376      91000          N
# 676       87000          N
# 342       87500          N
# 210       98000          N
# 438       90350          N
# 749       98000          N
# 1218      80500          N
# 61       101000          N
# 1011     100000          N
# 1090      92900          N
# 88        85000          N
# 514       96500          N

# %%
len(fp[fp['CentralAir']=='N'])
# Out:
# 24
