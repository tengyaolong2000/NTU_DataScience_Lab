# %%
#import required libarires
import pandas as pd
import numpy as np

# %% [markdown]
# **Problem 1**

# %% [markdown]
# a)

# %%
#pathname needs to be changed to correct pathname in different computers e.g. in lab. 
pathname = "/Users/tengyaolong/Desktop/NTU_DataScience_Lab/house-prices-advanced-regression-techniques/train.csv"

# %%
#import csv file into dataframe

train_df = pd.read_csv(pathname)
train_df.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# b)

# %%
train_df.shape
# Out:
# (1460, 81)

# %% [markdown]
# 1460 rows, 81 columns

# %% [markdown]
# c)

# %%
#check dtypes of all the columns

#note that yrsold is categorical although dtype is int64
train_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#to check dtype of specific column, e.g. LandContour, SalePrice. 'O' means object
print(train_df.LandContour.dtype)
print(train_df.SalePrice.dtype)
# Out:
# object
# int64

# %% [markdown]
# d)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# e)

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# **Problem 2**

# %% [markdown]
# a)

# %%
#may need conda install lxml

html_datas = pd.read_html("https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table")

# %%
print("Data type : ", type(html_datas))
print("HTML tables : ", len(html_datas))
# Out:
# Data type :  <class 'list'>
# HTML tables :  7

# %%
#table at index 2 is the actual 2016 Summer Olympics medal table
html_datas[2].head()
# Out:
#   Rank            NOC  Gold  Silver  Bronze  Total
# 0    1  United States    46      37      38    121
# 1    2  Great Britain    27      23      17     67
# 2    3          China    26      18      26     70
# 3    4         Russia    19      17      20     56
# 4    5        Germany    17      10      15     42

# %%
#store in new dataframe
olympic_table = html_datas[2]

# %%
#store top 20
top_twenty = html_datas[2].iloc[:20]
print(top_twenty)
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1  United States    46      37      38    121
# 1     2  Great Britain    27      23      17     67
# 2     3          China    26      18      26     70
# 3     4         Russia    19      17      20     56
# 4     5        Germany    17      10      15     42
# 5     6          Japan    12       8      21     41
# 6     7         France    10      18      14     42
# 7     8    South Korea     9       3       9     21
# 8     9          Italy     8      12       8     28
# 9    10      Australia     8      11      10     29
# 10   11    Netherlands     8       7       4     19
# 11   12        Hungary     8       3       4     15
# 12   13        Brazil*     7       6       6     19
# 13   14          Spain     7       4       6     17
# 14   15          Kenya     6       6       1     13
# 15   16        Jamaica     6       3       2     11
# 16   17        Croatia     5       3       2     10
# ...

# %% [markdown]
# **Bonus**

# %% [markdown]
# A)

# %%
census_df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data", names = ["age", "workclass", "fnlwgt", "education", "education-num", "marital-status", "occupation", "relationship", "race", "sex",
"capital-gain", "capital-loss", "hours-per-week", "native-country"], index_col=False)

# %%
census_df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0          2174             0              40   United-States
# ...

# %%
census_df.shape
# Out:
# (32561, 14)

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
census_df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# B)

# %%
top_dict = {}
for i in range(2000,2017,4):
    df = pd.read_html("https://en.wikipedia.org/wiki/"+str(i)+"_Summer_Olympics_medal_table")
    top_dict[i] = df[2].iloc[:20,1:].values.tolist()
    
    
#convert dict to dataframe
top_twenty_fouryrs = pd.DataFrame(data=top_dict)

# %%
#make index start from 1
top_twenty_fouryrs.index+=1

# %%
top_twenty_fouryrs
# Out:
#                                2000                              2004  \
# 1   [United States, 37, 24, 32, 93]  [United States, 36, 39, 26, 101]
# 2          [Russia, 32, 28, 29, 89]           [China, 32, 17, 14, 63]
# 3           [China, 28, 16, 14, 58]          [Russia, 28, 26, 36, 90]
# 4      [Australia*, 16, 25, 17, 58]       [Australia, 17, 16, 17, 50]
# 5         [Germany, 13, 17, 26, 56]            [Japan, 16, 9, 12, 37]
# 6          [France, 13, 14, 11, 38]         [Germany, 13, 16, 20, 49]
# 7            [Italy, 13, 8, 13, 34]           [France, 11, 9, 13, 33]
# 8       [Netherlands, 12, 9, 4, 25]           [Italy, 10, 11, 11, 32]
# 9             [Cuba, 11, 11, 7, 29]       [South Korea, 9, 12, 9, 30]
# 10   [Great Britain, 11, 10, 7, 28]     [Great Britain, 9, 9, 12, 30]
# 11          [Romania, 11, 6, 9, 26]              [Cuba, 9, 7, 11, 27]
# 12     [South Korea, 8, 10, 10, 28]            [Hungary, 8, 6, 3, 17]
# ...
